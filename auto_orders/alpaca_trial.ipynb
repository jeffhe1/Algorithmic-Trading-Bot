# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import GetAssetsRequest



trading_client = TradingClient(akey, skey)

# Get our account information.
account = trading_client.get_account()

# Check our current balance vs. our balance at the last market close
balance_change = float(account.equity) - float(account.last_equity)
print(f'Today\'s portfolio balance change: ${balance_change}')
# Out:
# Today's portfolio balance change: $0.0

# %%
akey = "PKDHUGPBZHOO15LB7DLY"
skey ="DtvLgeUJ9WlKTq7nBmbMwwNECccnaMJrdrKhWU3m"

# %%
from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockLatestQuoteRequest

# keys required for stock historical data client
client = StockHistoricalDataClient(akey, skey)

# multi symbol request - single symbol is similar
multisymbol_request_params = StockLatestQuoteRequest(symbol_or_symbols=["SPY", "GLD", "TLT"])

latest_multisymbol_quotes = client.get_stock_latest_quote(multisymbol_request_params)

gld_latest_ask_price = latest_multisymbol_quotes["GLD"].ask_price

latest_multisymbol_quotes
# Out:
# {'SPY': {   'ask_exchange': 'V',
#      'ask_price': 510.11,
#      'ask_size': 10.0,
#      'bid_exchange': 'V',
#      'bid_price': 506.71,
#      'bid_size': 10.0,
#      'conditions': ['R'],
#      'symbol': 'SPY',
#      'tape': 'B',
#      'timestamp': datetime.datetime(2024, 4, 26, 20, 59, 4, 333365, tzinfo=TzInfo(UTC))},
#  'TLT': {   'ask_exchange': 'V',
#      'ask_price': 88.36,
#      'ask_size': 13.0,
#      'bid_exchange': 'V',
#      'bid_price': 88.2,
#      'bid_size': 13.0,
#      'conditions': ['R'],
#      'symbol': 'TLT',
#      'tape': 'C',
#      'timestamp': datetime.datetime(2024, 4, 26, 20, 32, 9, 964, tzinfo=TzInfo(UTC))},
#  'GLD': {   'ask_exchange': 'V',
#      'ask_price': 218.92,
#      'ask_size': 5.0,
#      'bid_exchange': 'V',
#      'bid_price': 213.69,
#      'bid_size': 5.0,
#      'conditions': ['R'],
#      'symbol': 'GLD',
#      'tape': 'B',
#      'timestamp': datetime.datetime(2024, 4, 26, 20, 49, 35, 990912, tzinfo=TzInfo(UTC))}}

# %%
from alpaca.data.historical import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame
from datetime import datetime

# no keys required for crypto data
client = CryptoHistoricalDataClient()

request_params = CryptoBarsRequest(
                        symbol_or_symbols=["BTC/USD", "ETH/USD"],
                        timeframe=TimeFrame.Day,
                        start=datetime(2022, 7, 1),
                        end=datetime(2024, 4, 1)
                 )

bars = client.get_crypto_bars(request_params)

# convert to dataframe
bars.df

# access bars as list - important to note that you must access by symbol key
# even for a single symbol request - models are agnostic to number of symbols
bars["BTC/USD"]
# Out:
# [{   'close': 19170.27,
#      'high': 19764.83,
#      'low': 18940.0,
#      'open': 19374.83,
#      'symbol': 'BTC/USD',
#      'timestamp': datetime.datetime(2022, 7, 1, 5, 0, tzinfo=TzInfo(UTC)),
#      'trade_count': 118377.0,
#      'volume': 7521.574449,
#      'vwap': 19343.7428550912},
#  {   'close': 19231.67,
#      'high': 19441.9,
#      'low': 18752.98,
#      'open': 19170.9,
#      'symbol': 'BTC/USD',
#      'timestamp': datetime.datetime(2022, 7, 2, 5, 0, tzinfo=TzInfo(UTC)),
#      'trade_count': 64323.0,
#      'volume': 3459.369133,
#      'vwap': 19210.3198189685},
#  {   'close': 19102.36,
#      'high': 19625.32,
#      'low': 18911.68,
#      'open': 19233.4,
#      'symbol': 'BTC/USD',
#      'timestamp': datetime.datetime(2022, 7, 3, 5, 0, tzinfo=TzInfo(UTC)),
#      'trade_count': 101957.0,
#      'volume': 3478.188482,
#      'vwap': 19162.3038663075},
#  {   'close': 20251.12,
#      'high': 20450.89,
#      'low': 19057.69,
#      'open': 19101.41,
# ...

# %%
from alpaca.data.live import StockDataStream


wss_client = StockDataStream(akey, skey)

# async handler
async def quote_data_handler(data):
    # quote data will arrive here
    print(data)

wss_client.subscribe_quotes(quote_data_handler, "SPY")

wss_client.run()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\alpaca\common\websocket.py:447, in BaseStream.run(self)
#     446 try:
# --> 447     asyncio.run(self._run_forever())
#     448 except KeyboardInterrupt:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\asyncio\runners.py:33, in run(main, debug)
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
uri = "mongodb+srv://2211054370abc:c4usFL4cce9ZB4fS@cluster0.whiro9v.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import GetAssetsRequest
from alpaca.trading.enums import AssetClass

# paper=True enables paper trading
trading_client = TradingClient(akey, skey, paper=True)

search_params = GetAssetsRequest(asset_class=AssetClass.CRYPTO)

assets = trading_client.get_all_assets(search_params)

assets
# Out:
# [{   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('0515189d-1933-4a94-89ce-4e9a24356d58'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.02864919,
#      'min_trade_increment': 1e-09,
#      'name': 'Avalanche / US Dollar',
#      'price_increment': 0.0005,
#      'shortable': False,
#      'status': <AssetStatus.ACTIVE: 'active'>,
#      'symbol': 'AVAX/USD',
#      'tradable': True},
#  {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#      'attributes': [],
#      'easy_to_borrow': False,
#      'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#      'fractionable': True,
#      'id': UUID('b7b73bc2-e3bc-4b37-8fcf-4eac793027ef'),
#      'maintenance_margin_requirement': 100.0,
#      'marginable': False,
#      'min_order_size': 0.025826446,
# ...

# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import MarketOrderRequest
from alpaca.trading.enums import OrderSide, TimeInForce

trading_client = TradingClient(akey, skey, paper=True)

# preparing orders
market_order_data = MarketOrderRequest(
                    symbol="SPY",
                    qty=0.023,
                    side=OrderSide.BUY,
                    time_in_force=TimeInForce.DAY
                    )

# Market order
market_order = trading_client.submit_order(
                order_data=market_order_data
               )
# Out:
# []

# %%
from alpaca.data.live import StockDataStream
import asyncio
trading_stream = StockDataStream(akey, skey)

async def update_handler(data):
    # trade updates will arrive in our async handler
    print(data)

# subscribe to trade updates and supply the handler as a parameter
trading_stream.subscribe_trades(update_handler, "MSFT")

# start our websocket streaming
trading_stream.run()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\alpaca\common\websocket.py:447, in BaseStream.run(self)
#     446 try:
# --> 447     asyncio.run(self._run_forever())
#     448 except KeyboardInterrupt:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\asyncio\runners.py:33, in run(main, debug)
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
trading_client = TradingClient(akey, skey, paper=True)
market_order_data = MarketOrderRequest(
                    symbol="BTC/USD",
                    qty=0.023,
                    side=OrderSide.BUY,
                    time_in_force=TimeInForce.DAY
                    )

# %%
def example_function(a, b, c) :
    return(a)
r = example_function(1,2,3)
print(r)
async def example_coroutine_function(a, b, c) :
    return(a)

r = example_coroutine_function(1,2,3)

print(r)
# Out:
# 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [10], line 9
#       6     return(a)
#       8 r = example_coroutine_function(1,2,3)
# ----> 9 print(r.run())
#
# AttributeError: 'coroutine' object has no attribute 'run'
